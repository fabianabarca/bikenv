# %% [markdown]
# # Rapid test platform

# %%
import bikenv

# %%
G = bikenv.get_region("Cinco Esquinas de Tibás, San José, Costa Rica")

# %%
type(G)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
# Show methods and attributes of G
dir(G)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adj',
#  '_node',
#  '_pred',
#  '_succ',
#  'add_edge',
#  'add_edges_from',
#  'add_node',
#  'add_nodes_from',
#  'add_weighted_edges_from',
#  'adj',
#  'adjacency',
#  'adjlist_inner_dict_factory',
#  'adjlist_outer_dict_factory',
#  'clear',
#  'clear_edges',
#  'copy',
#  'degree',
#  'edge_attr_dict_factory',
#  'edge_key_dict_factory',
#  'edge_subgraph',
#  'edges',
#  'get_edge_data',
#  'graph',
#  'graph_attr_dict_factory',
#  'has_edge',
#  'has_node',
#  'has_predecessor',
# ...
